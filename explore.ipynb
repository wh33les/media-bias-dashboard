# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("media_sources_robust_influence.csv")

# Display the first few rows
df.head(2)
# Out:
#                     Moniker                 Main Url  Bias  Reliability  \
# 0  11Alive Atlanta NBC WXIA       http://11alive.com -3.86        45.75
# 1        ABC News (website)  https://abcnews.go.com/ -3.02        44.77
#
#       Mediatype  has_wikipedia_page  wikipedia_avg_daily_views  \
# 0  Web/Articles               False                        NaN
# 1  Web/Articles               False                        NaN
#
#    wikipedia_interest_score  domain_authority_score  audience_reach_score  \
# 0                       0.0                      50                    40
# 1                       0.0                      95                    40
#
#    estimated_audience_size  medium_tier  cross_platform_multiplier  \
# 0                   100000  tier3_other                        1.1
# 1                   100000  tier3_other                        1.1
#
#    robust_influence_score platform_type
# 0                   27.50     web_media
# 1                   32.45     web_media
