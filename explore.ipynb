# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("data/test_results.csv")

# Display the first few rows
df.head(10)
# Out:
#                     Moniker                  Main Url   Bias  Reliability  \
# 0        ABC News (website)   https://abcnews.go.com/  -3.02        44.77
# 1                       BBC      https://www.bbc.com/  -1.34        44.73
# 2             CNN (website)      https://www.cnn.com/  -6.19        42.13
# 3        Fox News (website)       http://foxnews.com/  11.06        35.31
# 4             NPR (website)      https://www.npr.org/  -4.23        43.10
# 5                   Reuters  https://www.reuters.com/  -1.25        44.98
# 6  11Alive Atlanta NBC WXIA        http://11alive.com  -3.86        45.75
# 7             Activist Post   http://activistpost.com  16.32        17.81
# 8         Advocate Magazine       http://advocate.com -12.21        40.00
# 9      Agence France-Presse    https://www.afp.com/en  -2.40        47.15
#
#       Mediatype has_wikipedia_page wikipedia_title  wikipedia_avg_daily_views  \
# ...
